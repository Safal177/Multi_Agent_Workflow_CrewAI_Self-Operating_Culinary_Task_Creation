# %%
"""
# Workflow Title:

Multi-Agent Workflow using CrewAI for Self-Operating Culinary Task Creation

# Overview:
•	CrewAI used for a team of agents communication is applicable for making independent AI workflows.
•	Agents can communicate tasks, synchronize knowledge, and yield reliable outputs
•	one example to support CrewAI self-operating AI pipeline included.
•	This project illustrates how AI carries a real-world multi-agent workflow in practical scenarios.

"""

# %%
"""
# Underlying Technologies:

•	Python programming
•	Google Colab
•	OpenAI: gpt-4o-mini as LLM
•	CrewAI used for multi-actor workflow including task conversation under the LLM infrastructure
•	Query Engineering under LLM

# Mission:

•	Make self-managed multi-agent system and run it.
•	Communicate between agents to make personalized recipes by keeping food preference rules.
•	Make logical decisions with a simple example using CrewAI’s flow pipeline.
•	Reproducible output received.

"""

# %%
"""
# Notable Points:

•	Created a multi-agent workflow under CrewAI.
•	culinary_agent working as LLM agent can understand how to manage food elements, nutritional restrictions, and user preferences.
•	Organized tasks through multiple ways: recipe planning, tuning, and result presentation
•	Presented self-directed engine using agentic logic and AI query structuring.
•	AI pipelines working under NLP fields.

"""

# %%
import os

# %%
#%%capture
#!pip install crewai

# %%
# using 'userdata' to read key
from google.colab import userdata

api_key = userdata.get('OPENAI_API_KEY')

os.environ['OPENAI_API_KEY'] = api_key

# %%
from crewai import LLM

#from crewai import Agent, Task, Crew, LLM

# setup an LLM with OpenAI model ('gpt-4o-mini')

llm = LLM(model = 'gpt-4o-mini')

# %%
# agent input setup

flavor_bases = ['garlic', 'chicken', 'mushroom', 'tofu']

food_allergies = ['nuts',  'red meat', 'high sodium', 'spicy foods']

# %%
from crewai import Agent

# change lists into text.
flavor_bases_list_text = ','.join(flavor_bases)
food_allergies_list_text = ','.join(food_allergies)

# Note: Do not rename the keyword arguments llm, role, backstory, goal, or verbose placed inside the Agent().

culinary_agent =  Agent(
    llm=llm,
    role = 'culinary_agent',
    backstory=(
        'You are a professional culinary AI helper with clear understanding how to build recipes through smart taste matching and nutritional knowledge.'
        'You make meals that use recipe elements with respect to all food sensitivities.'),
    goal = (
    f'Make recipes which incorporate any of the highlighted flavor components: {flavor_bases_list_text}.'
    f'Drop out any food items connected to these dietary boundaries: {food_allergies_list_text}.'
    f'After selecting a recipe, guide the user with clear instructions of the cooking protocol.'
),
    verbose=True,
)

"""
For general understanding about crewai, I use one Agent() in this CrewAI task. With CrewAI, we can choose more than one Agent(). Each Agent has a different role,
goal, and backstory with different responsibilities. For example, we can choose 2 Agents such as culinary_agent, and dietary_agent.

 """
# Out:
# '\nFor general understanding about crewai, I use one Agent() in this CrewAI task. With CrewAI, we can choose more than one Agent(). Each Agent has a different role,\ngoal, and backstory with different responsibilities. For example, we can choose 2 Agents such as culinary_agent, and dietary_agent.\n\n '

# %%
# I am defining 3 tasks with 1 agent. However, CrewAI gives opportunities to choose any number of tasks with 1 or more different agents.

# %%
from crewai import Task

# Task 1: Search recipe choices according to flavor_bases, and food_allergies

search_recipes_task  =  Task(
    description = ('Use the provided flavor parts, drop avoided allergens, and make at least three recipes with core components and a short explanation.'),

    expected_output = ' Provide a minimum of 3 recipes along with an overview of necessary ingredients.',

    agent = culinary_agent,
)

# %%
# Task 2: Take your best recipe.
select_best_recipe_task = Task(
    description = (
        'Overview all suggested recipes and then analyze them.'
        'Select a recipe that has test quality as well as dietary criteria.'
        'Give us some reasons behind your decision.'),

    expected_output = 'Final recipe as well as reasoning for your choice.',

    agent = culinary_agent,)

# %%
# Task # 3: Make an end-to-end recipe workflow
make_cooking_steps_task = Task(
    description = (
        'Put the selected recipe into an organized as well as clear explained cooking manual.'
        'Provide some details including cooking time, temperature limit, and helpful recommendations.'),

    expected_output = 'provide a completed cooking instructions in sequential order.',

    agent = culinary_agent,)

# %%
# State the Crew with a agent and tasks
# are tasks required in order? Left for research
# Define the Crew (group of agents + tasks working in sequence)

from crewai import Crew

kitchen_crew  = Crew(
    agents = [culinary_agent],
    tasks  =  [search_recipes_task, select_best_recipe_task, make_cooking_steps_task],
    planning = True,
    verbose = True,
)

# %%
# Run all tasks if they are in order.
outcomes_culinary_crew = kitchen_crew.kickoff()
# Out:
# [2025-11-07 00:52:39][INFO]: Planning the crew execution
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 1231d17c-3ce4-4b8c-b876-de0553ee366f                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: a8fee752-bb83-4048-9d30-45fd2ac2454b                                                                     │
# │  Agent: Task Execution Planner                                                                                  │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: culinary_agent                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are three delicious recipes that incorporate the highlighted flavor components of garlic, chicken,        │
# │  mushrooms, and tofu while avoiding allergens such as nuts, red meat, high sodium, and spicy foods.             │
# │                                                                                                                 │
# │  ### Recipe 1: Garlic Chicken Stir-fry                                                                          │
# │  **Core Components:**                                                                                           │
# │  - Chicken breast (cut into bite-sized pieces)                                                                  │
# │  - Minced garlic                                                                                                │
# │  - Mixed vegetables (like bell peppers, broccoli, and carrots)                                                  │
# │  - Olive oil                                                                                                    │
# │  - Low-sodium soy sauce (optional)                                                                              │
# │                                                                                                                 │
# │  **Overview:**                                                                                                  │
# │  This stir-fry is quick and easy to make, perfect for a weeknight dinner. The chicken is sautéed in olive oil   │
# │  until golden, then garlic and vegetables are added to add flavor and color. You can also add low-sodium soy    │
# │  sauce for an extra punch, keeping everything tasty yet healthy.                                                │
# │                                                                                                                 │
# │  **Instructions:**                                                                                              │
# │  1. Heat olive oil in a large skillet over medium-high heat.                                                    │
# │  2. Add the chicken pieces and cook until they are no longer pink, stirring occasionally (approximately 5-6     │
# │  minutes).                                                                                                      │
# │  3. Stir in minced garlic and cook for 1 additional minute until fragrant.                                      │
# │  4. Add mixed vegetables and stir-fry for another 5 minutes until they are tender-crisp.                        │
# │  5. Optionally, drizzle low-sodium soy sauce for flavor and serve immediately over rice or quinoa.              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Recipe 2: Mushroom Tofu Soup                                                                               │
# │  **Core Components:**                                                                                           │
# │  - Firm tofu (cubed)                                                                                            │
# │  - Fresh mushrooms (sliced)                                                                                     │
# │  - Garlic (minced)                                                                                              │
# │  - Vegetable broth (low-sodium)                                                                                 │
# │  - Spinach or kale (for added nutrition)                                                                        │
# │                                                                                                                 │
# │  **Overview:**                                                                                                  │
# │  This comforting soup is packed with nutrients and flavor. Tofu provides protein while mushrooms add a hearty   │
# │  texture. The garlic infuses the broth with warmth, and leafy greens enhance the dish's health benefits.        │
# │                                                                                                                 │
# │  **Instructions:**                                                                                              │
# │  1. In a pot, heat a splash of olive oil and sauté minced garlic for about 1 minute.                            │
# │  2. Add sliced mushrooms and cook until they are soft (about 3-4 minutes).                                      │
# │  3. Pour in vegetable broth and bring to a boil.                                                                │
# │  4. Lower the heat, add cubed tofu and let it simmer for 10 minutes.                                            │
# │  5. Stir in spinach or kale and cook until wilted.                                                              │
# │  6. Season to taste with additional garlic or pepper (not spicy) and serve hot.                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Recipe 3: Garlic Mushroom Chicken Bake                                                                     │
# │  **Core Components:**                                                                                           │
# │  - Chicken thighs (or breasts)                                                                                  │
# │  - Sliced mushrooms                                                                                             │
# │  - Minced garlic                                                                                                │
# │  - Olive oil                                                                                                    │
# │  - Fresh thyme or rosemary (optional for garnish)                                                               │
# │                                                                                                                 │
# │  **Overview:**                                                                                                  │
# │  A simple yet flavorful baked dish, this recipe combines chicken with the earthiness of mushrooms and garlic.   │
# │  Baking the dish allows the flavors to meld beautifully, creating a juicy and satisfying meal.                  │
# │                                                                                                                 │
# │  **Instructions:**                                                                                              │
# │  1. Preheat the oven to 375°F (190°C).                                                                          │
# │  2. In a baking dish, place chicken thighs/breasts and season with salt, pepper, and minced garlic.             │
# │  3. Add sliced mushrooms on top of the chicken and drizzle with olive oil.                                      │
# │  4. Toss everything together to ensure even coating.                                                            │
# │  5. Bake in the oven for 25-30 minutes until the chicken is cooked through and golden, stirring halfway.        │
# │  6. Garnish with fresh herbs if using and serve warm.                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Summary of Necessary Ingredients:                                                                          │
# │  - Chicken breast/thighs                                                                                        │
# │  - Firm tofu                                                                                                    │
# │  - Fresh mushrooms                                                                                              │
# │  - Garlic                                                                                                       │
# │  - Olive oil                                                                                                    │
# │  - Mixed vegetables (bell peppers, broccoli, carrots)                                                           │
# │  - Spinach or kale                                                                                              │
# │  - Vegetable broth (low-sodium)                                                                                 │
# │  - Fresh thyme or rosemary (optional)                                                                           │
# │  - Low-sodium soy sauce (optional)                                                                              │
# │                                                                                                                 │
# │  With these recipes, you can enjoy delicious meals without any allergens, featuring the wonderful flavors of    │
# │  garlic, chicken, mushrooms, and tofu!                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: culinary_agent                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  After reviewing the three recipes—Garlic Chicken Stir-fry, Mushroom Tofu Soup, and Garlic Mushroom Chicken     │
# │  Bake—I have analyzed them for taste quality, presentation, and dietary criteria.                               │
# │                                                                                                                 │
# │  **Recipe Analysis:**                                                                                           │
# │                                                                                                                 │
# │  1. **Garlic Chicken Stir-fry**                                                                                 │
# │     - **Taste Quality:** The combination of sautéed chicken and vibrant mixed vegetables, enhanced by garlic,   │
# │  results in a dish that is aromatic and visually appealing.                                                     │
# │     - **Presentation:** The colorful mix of vegetables with chicken makes it visually satisfying, as the        │
# │  colors contrast nicely.                                                                                        │
# │     - **Dietary Criteria:** It meets all dietary restrictions by avoiding allergens and high sodium             │
# │  ingredients.                                                                                                   │
# │                                                                                                                 │
# │  2. **Mushroom Tofu Soup**                                                                                      │
# │     - **Taste Quality:** This soup provides a comforting experience with warm flavors from garlic and a smooth  │
# │  texture from the tofu and mushrooms.                                                                           │
# │     - **Presentation:** While soups are generally liquid-based and may not appear as colorful, the vibrant      │
# │  green from spinach or kale adds visual appeal.                                                                 │
# │     - **Dietary Criteria:** It adheres to dietary requirements, but the presentation may not be as hearty as    │
# │  the stir-fry for those looking for a filling meal.                                                             │
# │                                                                                                                 │
# │  3. **Garlic Mushroom Chicken Bake**                                                                            │
# │     - **Taste Quality:** The melding of flavors through baking creates a delicious and savory dish, with the    │
# │  mushrooms and garlic infusing the chicken.                                                                     │
# │     - **Presentation:** Baked dishes are often attractive when served, though less interactive than the         │
# │  stir-fry.                                                                                                      │
# │     - **Dietary Criteria:** It meets dietary restrictions effectively, but relies on a longer cooking time      │
# │  compared to a stir-fry.                                                                                        │
# │                                                                                                                 │
# │  **Selection of Recipe: Garlic Chicken Stir-fry**                                                               │
# │  - **Quick Preparation:** This dish boasts a quick preparation time, making it ideal for weeknight dinners,     │
# │  which is important for those with busy schedules.                                                              │
# │  - **Fresh Ingredients:** It highlights fresh vegetables alongside protein, ensuring a nutritious meal.         │
# │  - **Flavor Profile:** The garlic flavor is prominent yet balanced, and the inclusion of mixed veggies          │
# │  showcases a multitude of textures and tastes.                                                                  │
# │  - **Customer Satisfaction:** This recipe tends to receive a high rating among diners due to its balanced       │
# │  flavors and satisfying quality.                                                                                │
# │                                                                                                                 │
# │  **Documenting the Reason**                                                                                     │
# │  The garlic chicken stir-fry stands out as the best choice due to its accessibility, adherence to dietary       │
# │  restrictions, and proven customer satisfaction. It encapsulates the highlighted flavors—garlic and             │
# │  chicken—while also allowing for additional nutritious components in the mixed vegetables. The joyful           │
# │  combination makes it a favorite for both cooking and enjoying.                                                 │
# │                                                                                                                 │
# │  **Cooking Protocol for Garlic Chicken Stir-fry:**                                                              │
# │  1. Heat 1 tablespoon of olive oil in a large skillet over medium-high heat.                                    │
# │  2. Add bite-sized pieces of chicken breast and cook for about 5-6 minutes, stirring occasionally, until no     │
# │  longer pink.                                                                                                   │
# │  3. Stir in 2-3 minced garlic cloves and cook for an additional minute until fragrant.                          │
# │  4. Incorporate about 2 cups of mixed vegetables (such as bell peppers, broccoli, and carrots) and stir-fry     │
# │  for another 5 minutes until vegetables are tender-crisp.                                                       │
# │  5. Optionally, drizzle with low-sodium soy sauce for added flavor and serve immediately over a bed of rice or  │
# │  quinoa.                                                                                                        │
# │                                                                                                                 │
# │  This method results in a delicious, visually appealing meal that respects dietary boundaries while             │
# │  brilliantly showcasing the highlighted flavors.                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 14643082-3ec4-4968-81d6-c7532435a671                                                                     │
# │  Agent: culinary_agent                                                                                          │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: culinary_agent                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Garlic Chicken Stir-fry Cooking Manual                                                                     │
# │                                                                                                                 │
# │  #### Ingredients:                                                                                              │
# │  - 1 lb (450g) chicken breast, cut into bite-sized pieces                                                       │
# │  - 2-3 cloves of garlic, minced                                                                                 │
# │  - 2 cups mixed vegetables (e.g., bell peppers, broccoli, carrots)                                              │
# │  - 1 tablespoon olive oil                                                                                       │
# │  - Optional: Low-sodium soy sauce for flavor                                                                    │
# │                                                                                                                 │
# │  #### Cooking Instructions:                                                                                     │
# │                                                                                                                 │
# │  1. **Prepare the Chicken**:                                                                                    │
# │     - Take 1 lb of chicken breast and cut it into bite-sized pieces. Set aside in a bowl.                       │
# │                                                                                                                 │
# │  2. **Mince the Garlic**:                                                                                       │
# │     - Peel and finely mince 2-3 cloves of garlic.                                                               │
# │                                                                                                                 │
# │  3. **Heat the Oil**:                                                                                           │
# │     - In a large skillet, heat 1 tablespoon of olive oil over medium-high heat until it shimmers.               │
# │                                                                                                                 │
# │  4. **Cook the Chicken**:                                                                                       │
# │     - Add the chicken pieces to the hot skillet. Cook for about 5-6 minutes, stirring occasionally, until the   │
# │  chicken is no longer pink in the center.                                                                       │
# │                                                                                                                 │
# │  5. **Add the Garlic**:                                                                                         │
# │     - Stir in the minced garlic and sauté for an additional 1 minute, or until fragrant.                        │
# │                                                                                                                 │
# │  6. **Incorporate Vegetables**:                                                                                 │
# │     - Add 2 cups of mixed vegetables to the skillet. Stir-fry for another 5 minutes, or until the vegetables    │
# │  are tender-crisp.                                                                                              │
# │                                                                                                                 │
# │  7. **Optional Seasoning**:                                                                                     │
# │     - If desired, drizzle with low-sodium soy sauce and stir to combine. Cook for an additional minute to meld  │
# │  flavors.                                                                                                       │
# │                                                                                                                 │
# │  8. **Serve**:                                                                                                  │
# │     - Serve the stir-fry hot over a bed of rice or quinoa for a complete meal.                                  │
# │                                                                                                                 │
# │  #### Cooking Details:                                                                                          │
# │  - **Cooking Time**: Approximately 15 minutes                                                                   │
# │  - **Temperature Setting**: Medium-high heat                                                                    │
# │                                                                                                                 │
# │  #### Helpful Recommendations:                                                                                  │
# │  - **Serving Suggestions**: Serve hot with rice or noodles for a satisfying meal.                               │
# │  - **Vegetable Variations**: Feel free to adjust the types of vegetables according to personal preferences.     │
# │  You can include snap peas, carrots, or any other favorites.                                                    │
# │                                                                                                                 │
# │  This Garlic Chicken Stir-fry is a quick, nutritious meal that is comforting and packed with flavor, making it  │
# │  perfect for busy weeknight dinners. Enjoy your delicious creation!                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# Like to see clean text

print(outcomes_culinary_crew.raw)
# Out:
# ### Garlic Chicken Stir-fry Cooking Manual
#
# #### Ingredients:
# - 1 lb (450g) chicken breast, cut into bite-sized pieces
# - 2-3 cloves of garlic, minced
# - 2 cups mixed vegetables (e.g., bell peppers, broccoli, carrots)
# - 1 tablespoon olive oil
# - Optional: Low-sodium soy sauce for flavor
#
# #### Cooking Instructions:
#
# 1. **Prepare the Chicken**:
#    - Take 1 lb of chicken breast and cut it into bite-sized pieces. Set aside in a bowl.
#
# 2. **Mince the Garlic**:
#    - Peel and finely mince 2-3 cloves of garlic.
#
# 3. **Heat the Oil**:
#    - In a large skillet, heat 1 tablespoon of olive oil over medium-high heat until it shimmers.
#
# 4. **Cook the Chicken**:
#    - Add the chicken pieces to the hot skillet. Cook for about 5-6 minutes, stirring occasionally, until the chicken is no longer pink in the center.
#
# 5. **Add the Garlic**:
#    - Stir in the minced garlic and sauté for an additional 1 minute, or until fragrant.
#
# 6. **Incorporate Vegetables**:
#    - Add 2 cups of mixed vegetables to the skillet. Stir-fry for another 5 minutes, or until the vegetables are tender-crisp.
#
# 7. **Optional Seasoning**:
#    - If desired, drizzle with low-sodium soy sauce and stir to combine. Cook for an additional minute to meld flavors.
#
# 8. **Serve**:
#    - Serve the stir-fry hot over a bed of rice or quinoa for a complete meal.
#
# #### Cooking Details:
# - **Cooking Time**: Approximately 15 minutes
# - **Temperature Setting**: Medium-high heat
#
# #### Helpful Recommendations:
# - **Serving Suggestions**: Serve hot with rice or noodles for a satisfying meal.
# - **Vegetable Variations**: Feel free to adjust the types of vegetables according to personal preferences. You can include snap peas, carrots, or any other favorites.
#
# This Garlic Chicken Stir-fry is a quick, nutritious meal that is comforting and packed with flavor, making it perfect for busy weeknight dinners. Enjoy your delicious creation!

# %% [markdown]
# # using CrewAI for marketing research with multiple products

# %%
#%%capture
#!pip install crewai-tools

# %%
# SerperDevTool acting as a tool to search real time internet data.

from crewai_tools import SerperDevTool

# %%
market_products_list =  [ 'protein snack', 'organic green tea']


marketing_experience = [
    'A goal focused marketing way supports on promoting healthy snacks as well as organic drinks with keeping brand name and holding customer participation.',
    'A marketing data analyst skilled in understanding consumer behavior, market competition, and campaigning strategies for healthy snacks, and organic beverages.',
    'A marketing expert showed for planning to launch products, research on market trends, and find target audiences for protein snack, organic green tea, and other healthy products.'
]

# %%
market_products_list_text = ','.join(market_products_list)
marketing_experience_text = ','.join(marketing_experience)

# %%
# Import necessary CrewAI classes

from crewai import Agent

# Agent # 1: Market Trends Specialist
Market_trends_specialist = Agent(
    role = 'Market Trends Specialist',

    goal = (f'Research on market patterns, understand buyer habits, and observe competitive approaches: {market_products_list_text}.'),

    backstory=('You have enough skills for market research as well asl market analysis.'
        ' Good experience for analyzing market signals and finding market growth possibilities.'),

    tools=[SerperDevTool()],
    verbose = True)

# %%
# Agent # 2: make some strategies based on market analysis

advisor = Agent(
    role = 'product improvement strategist',

    goal=(
        'Use market understanding to find results focused '
        f'marketing and Product identity approaches for these items: {market_products_list_text}.'),

    backstory=(
        f' You have solid experience in {marketing_experience_text}, so that your role is good for a brand strategist.'),
    verbose=True)

# %%
#  Task # 1: Run market analysis
collect_market_analysis_task  = Task(
    description=(
        f'Run online research to take key market patterns,'
        f'For {market_products_list_text}, it is demanding to focus for customer interest and market competition.'),

    expected_output = (
        'Report on current market patterns, and main competitors  including consumer preferences.'),
    agent = Market_trends_specialist)

# %%
# Task # 2: Generate market brand strategy plan

generate_market_brand_strategy_plan = Task(
    description=(
        f'make Brand identity alignment with best product using strategic approach involved in {market_products_list_text}.'
        'cover the focus group, and Key benefits with action plan.'
    ),

    expected_output = 'End to end marketing approach with covering target audience, and recommended actions  for market strategy.',

    agent = advisor,

    verbose = True
)

# %%
# link agents with tasks using Crew

crew_agents_tasks = Crew(

    agents = [Market_trends_specialist, advisor],

    tasks = [collect_market_analysis_task, generate_market_brand_strategy_plan],

    planning = True,

    verbose = True
)

# %%
from getpass import getpass

os.environ['SERPER_API_KEY'] = getpass('Super api key ')

print('super api key loaded and hided.')
# Out:
# Super api key ··········
# super api key loaded and hided.

# %%
# Run pipeline
crew_agents_tasks_results = crew_agents_tasks.kickoff()
# Out:
# Output()
# [2025-11-07 00:55:59][INFO]: Planning the crew execution
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: b9478bd4-2686-4818-91ee-8428f30223c1                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: f3076fc8-b761-48c0-bedf-1bcb5f55159c                                                                     │
# │  Agent: Task Execution Planner                                                                                  │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Trends Specialist                                                                                │
# │                                                                                                                 │
# │  Thought: Thought: To begin the research, I need to define precise search queries for understanding market      │
# │  patterns, customer interests, and competitor analysis for protein snacks and organic green tea. Then, I'll     │
# │  execute searches using the Serper tool starting with "current market trends for protein snacks" and "customer  │
# │  preferences for organic green tea." After gathering the first 10 results for each, I will analyze them and     │
# │  compile the structured report.                                                                                 │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "current market trends for protein snacks"                                                   │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'current market trends for protein snacks', 'type': 'search', 'num': 10, 'engine':  │
# │  'google'}, 'organic': [{'title': 'The Rise of Protein Snacking: Insights for Food Manufacturers', 'link':      │
# │  'https://www.glanbianutritionals.com/en/nutri-knowledge-center/insights/rise-protein-snacking', 'snippet':     │
# │  'Protein snack sales continue to grow, with US food giants taking action to tap this market. · Snacks with     │
# │  protein are desired across generations, ...', 'position': 1}, {'title': 'Study on the protein snack            │
# │  phenomenon - Chomps', 'link':                                                                                  │
# │  'https://chomps.com/pages/study-on-the-protein-snack-phenomenon?srsltid=AfmBOopCxxxExPYcJgQ8mmGHmoC3bWOX8jXi-  │
# │  NG6YYyZpI-SGdr9ryQJ', 'snippet': 'Younger Consumers Are Driving Growth: Gen Z and Millennial consumers are     │
# │  driving protein snacking, representing ~34% of protein snack consumers ...', 'position': 2}, {'title':         │
# │  'Insights: The rise of protein snacking - Glanbia', 'link':                                                    │
# │  'https://www.glanbia.com/news/insights-rise-protein-snacking', 'snippet': 'The category experienced an 8%      │
# │  sales increase over the prior year, with notable growth in protein bars (+3.8%), protein cereal (+10.3%), and  │
# │  ...', 'position': 3}, {'title': 'Protein Snacks Market Size, Trends & Growth 2025 to 2035', 'link':            │
# │  'https://www.futuremarketinsights.com/reports/protein-snacks-market', 'snippet': 'The global Protein Snacks    │
# │  Market is estimated to account for USD 4.92 billion in 2025. It is anticipated to grow at a CAGR of 9.1%       │
# │  during the assessment period.', 'position': 4}, {'title': "Protein Market Trends: What's Driving Success? -    │
# │  Numerator", 'link': 'https://www.numerator.com/resources/blog/protein-trends/', 'snippet': 'Over the past      │
# │  four years, protein-fortified salty snacks and desserts have posted strong household and trip growth, far      │
# │  outpacing their more ...', 'position': 5}, {'title': "What's going on with proteins? - Sevendots", 'link':     │
# │  'https://sevendots.com/whats-ggoing-on-with-proteins/', 'snippet': "Protein Snacks: expected to be wor...      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Trends Specialist                                                                                │
# │                                                                                                                 │
# │  Thought: Thought: Now I have preliminary data on current market trends for protein snacks, including growth    │
# │  rates, consumer demographics (notably Gen Z and millennials), market size forecasts, and main trends like      │
# │  demand for healthy, protein-rich, low-sugar snacks. Next, I need to perform a similar search for "customer     │
# │  preferences for organic green tea" to understand market patterns and consumer interests in that category.      │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Trends Specialist                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Report: Market Patterns, Consumer Preferences, and Competition Analysis for Protein Snacks and Organic Green   │
# │  Tea                                                                                                            │
# │                                                                                                                 │
# │  1. Protein Snacks                                                                                              │
# │                                                                                                                 │
# │  Market Trends:                                                                                                 │
# │                                                                                                                 │
# │  - The global protein snacks market is anticipated to grow from approximately USD 4.92 billion in 2025 to an    │
# │  estimated USD 74.1 billion by 2034.                                                                            │
# │  - Compound annual growth rates (CAGR) range between 7.0% to 12.1%, driven primarily by health-conscious        │
# │  consumers seeking nutritious, convenient snack options.                                                        │
# │  - Key categories experiencing sales upsurge include protein bars (+3.8% growth), protein cereals (+10.3%),     │
# │  and protein-fortified salty snacks and desserts.                                                               │
# │  - Millennials and Gen Z represent the dominant consumer base, with over 50% actively increasing protein        │
# │  intake.                                                                                                        │
# │  - The protein snacks market benefits from lifestyle trends emphasizing fitness, satiety, and clean-label       │
# │  products (e.g., low sugar, natural ingredients).                                                               │
# │                                                                                                                 │
# │  Consumer Preferences:                                                                                          │
# │                                                                                                                 │
# │  - High protein content combined with low sugar levels.                                                         │
# │  - Products with clean labels, natural and transparent ingredient sourcing.                                     │
# │  - Convenient, ready-to-eat formats well-suited to on-the-go consumption.                                       │
# │  - Innovative flavors and diverse formats to maintain consumer interest.                                        │
# │  - Growing but secondary attention to sustainability and ethical sourcing.                                      │
# │                                                                                                                 │
# │  Competitive Landscape:                                                                                         │
# │                                                                                                                 │
# │  - Market leaders include established nutrition and snack manufacturers expanding offerings.                    │
# │  - A mix of large food corporations and innovative startups drive market innovation.                            │
# │  - Brand differentiation through ingredient quality, health benefits claims, and flavor innovation.             │
# │  - Emerging attention on sustainability and product transparency is shaping competitive strategy.               │
# │                                                                                                                 │
# │  2. Organic Green Tea                                                                                           │
# │                                                                                                                 │
# │  Market Trends:                                                                                                 │
# │                                                                                                                 │
# │  - Organic green tea market is growing steadily alongside rising health-conscious consumer behavior and demand  │
# │  for sustainable products.                                                                                      │
# │  - Expansion of organic and eco-friendly certifications play a significant role in purchase decisions.          │
# │  - Market growth supported by health benefits—antioxidants, anti-inflammatory properties, cardiovascular and    │
# │  immune support.                                                                                                │
# │  - Growth particularly strong among millennials and urban customers who prioritize both taste and ethical       │
# │  sourcing.                                                                                                      │
# │  - Broadened retail availability, including online platforms, fuels accessibility and awareness.                │
# │                                                                                                                 │
# │  Consumer Preferences:                                                                                          │
# │                                                                                                                 │
# │  - Strong preference for certified organic products ensuring purity and safety.                                 │
# │  - Emphasis on eco-friendly packaging and sustainable production methods.                                       │
# │  - Importance of taste, freshness, and nutritive value.                                                         │
# │  - Recognition of health benefits such as immune system boosting, weight management.                            │
# │  - Varied demographic preferences: millennials favor sustainable packaging and novel formats; older consumers   │
# │  prefer traditional standard green tea.                                                                         │
# │                                                                                                                 │
# │  Competitive Landscape:                                                                                         │
# │                                                                                                                 │
# │  - Established tea companies leverage consumer insights to tailor organic, sustainable offerings.               │
# │  - Specialty brands emphasize authenticity, ethical sourcing, and environmental impact reduction.               │
# │  - Certifications and clear communication regarding sustainability and health claims are competitive            │
# │  advantages.                                                                                                    │
# │  - Multi-channel retail strategies enhance product availability and discovery.                                  │
# │                                                                                                                 │
# │  Summary:                                                                                                       │
# │                                                                                                                 │
# │  The protein snack and organic green tea markets are both shaped by health, wellness, and sustainability        │
# │  trends but differ slightly in consumer drivers. Protein snacks attract younger, fitness-focused consumers      │
# │  seeking convenience and functional nutrition, while organic green tea appeals strongly to health-conscious     │
# │  consumers valuing sustainability, certification, and traditional quality. The competitive landscape in both    │
# │  markets involves established brands innovating and newer entrants capitalizing on niche trends, with           │
# │  sustainability and transparency increasingly important competitive facets.                                     │
# │                                                                                                                 │
# │  This report can be supplemented with market size growth charts and consumer preference attribute maps for a    │
# │  more visual representation of trends.                                                                          │
# │                                                                                                                 │
# │  End of Report.                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: product improvement strategist                                                                          │
# │                                                                                                                 │
# │  Task: make Brand identity alignment with best product using strategic approach involved in protein             │
# │  snack,organic green tea.cover the focus group, and Key benefits with action plan.1. Review the report created  │
# │  from the previous task to understand market positioning and consumer preferences. 2. Identify the target       │
# │  audience segments for both protein snacks and organic green tea based on the gathered data. 3. Define key      │
# │  benefits of the products that align with the target audience's preferences and lifestyle. 4. Conduct           │
# │  discussions or workshops with the focus group to brainstorm effective brand identity elements that resonate    │
# │  with the target audience. 5. Develop a comprehensive marketing strategy outlining how to present the           │
# │  product's identity—tags, slogans, and visual branding elements. 6. Create an action plan with recommended      │
# │  activities for market engagement, including social media campaigns, influencer partnerships, and               │
# │  knowledgeable content creation. 7. Specify timelines and responsibilities for each action item in the          │
# │  marketing strategy. 8. Review and refine the marketing plan ensuring it aligns with consumer insights and      │
# │  brand identity before rolling it out.                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: e3635906-9665-4c28-b8d7-66050f92c271                                                                     │
# │  Agent: Market Trends Specialist                                                                                │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: product improvement strategist                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Brand Identity Alignment & Strategic Marketing Approach for Protein Snack and Organic Green Tea                │
# │                                                                                                                 │
# │  1. Review & Market Positioning Summary                                                                         │
# │  Based on the previous comprehensive report, the protein snack market is rapidly growing with strong demand     │
# │  from Millennials and Gen Z who prioritize high protein, low sugar, clean labels, and convenience. The organic  │
# │  green tea market is steadily expanding with consumers emphasizing certified organic quality, sustainability,   │
# │  and health benefits, particularly immune support and antioxidants, appealing mainly to health-conscious        │
# │  Millennials and urban demographics.                                                                            │
# │                                                                                                                 │
# │  2. Target Audience Segments                                                                                    │
# │                                                                                                                 │
# │  Protein Snacks:                                                                                                │
# │  - Primary: Millennials and Gen Z (ages 18-35), fitness enthusiasts, active lifestyles, urban residents         │
# │  seeking convenient, nutritious snacks.                                                                         │
# │  - Secondary: Health-aware professionals desiring balanced nutrition on-the-go, parents looking for healthy     │
# │  kid snacks.                                                                                                    │
# │                                                                                                                 │
# │  Organic Green Tea:                                                                                             │
# │  - Primary: Health-conscious Millennials and urban consumers (ages 25-45), emphasizing sustainability, ethical  │
# │  sourcing, and antioxidant-rich beverages for wellness.                                                         │
# │  - Secondary: Older consumers (45+) who value traditional, high-quality green tea with proven health benefits.  │
# │                                                                                                                 │
# │  3. Key Product Benefits Aligned with Target Audience Preferences                                               │
# │                                                                                                                 │
# │  Protein Snack:                                                                                                 │
# │  - High-quality, natural protein content supporting fitness and satiety.                                        │
# │  - Low sugar with clean label ingredients ensuring transparency and health.                                     │
# │  - Ready-to-eat, convenient packaging for busy lifestyles.                                                      │
# │  - Flavor innovation to maintain interest and enjoyment.                                                        │
# │  - Ethical sourcing aligning with emerging sustainability concerns.                                             │
# │                                                                                                                 │
# │  Organic Green Tea:                                                                                             │
# │  - Certified organic, guaranteeing purity and safety with authentic taste.                                      │
# │  - Sustainable and eco-friendly packaging catering to environmentally conscious consumers.                      │
# │  - Rich antioxidant and anti-inflammatory properties promoting immune support and overall wellness.             │
# │  - Freshness and nutritive value to align with health priorities.                                               │
# │  - Story of ethical sourcing and environmental stewardship.                                                     │
# │                                                                                                                 │
# │  4. Focus Group Workshops & Brand Identity Element Brainstorming                                                │
# │  Facilitate interactive sessions with representatives from each target group to identify desired brand          │
# │  attributes and emotional triggers:                                                                             │
# │                                                                                                                 │
# │  Protein Snack Focus Group Insights:                                                                            │
# │  - Brand imagery evoking vitality, active lifestyle, and trustworthiness.                                       │
# │  - Preferred tonal language: energetic, motivating, transparent.                                                │
# │  - Visual elements: vibrant colors with natural tones, sleek modern packaging design.                           │
# │  - Tagline suggestions: “Fuel Your Hustle” / “Power Naturally” / “Clean Energy Bites.”                          │
# │                                                                                                                 │
# │  Organic Green Tea Focus Group Insights:                                                                        │
# │  - Brand identity around harmony, purity, and sustainability.                                                   │
# │  - Language: calm, refreshing, reassuring.                                                                      │
# │  - Visual elements: earthy green shades, minimalist eco-friendly packaging, nature-inspired visuals.            │
# │  - Taglines: “Nature’s Purest Brew” / “Sip Sustainably, Live Healthily.”                                        │
# │                                                                                                                 │
# │  5. Comprehensive Marketing Strategy                                                                            │
# │                                                                                                                 │
# │  Product Identity Presentation:                                                                                 │
# │  - Protein Snack: Position as the clean, innovative protein source for on-the-go health-focused consumers. Use  │
# │  brand tags emphasizing natural energy and transparency. Incorporate vibrant, active lifestyle imagery and      │
# │  straightforward health claims on packaging and advertising.                                                    │
# │  - Organic Green Tea: Highlight certified organic status, sustainability credentials, and health benefits with  │
# │  storytelling marketing. Use serene visual branding with green and earth tones, eco-friendly packaging          │
# │  highlights, and customer testimonials.                                                                         │
# │                                                                                                                 │
# │  Key Marketing Components:                                                                                      │
# │  - Social media campaigns targeting fitness and wellness communities for protein snack, using influencers who   │
# │  align with clean eating and active lifestyle. Instagram reels, TikTok challenges demonstrating usage in        │
# │  workout routines.                                                                                              │
# │  - Organic Green Tea campaigns focusing on sustainability and wellness influencers, educational content on      │
# │  health benefits via blogs and YouTube, and partnerships with eco-conscious online retailers.                   │
# │  - Cross-promotion strategies bundling protein snacks with green tea as complementary health products.          │
# │                                                                                                                 │
# │  6. Action Plan with Market Engagement Activities                                                               │
# │                                                                                                                 │
# │  Action Items:                                                                                                  │
# │  - Launch teaser campaign and product reveals on Instagram, TikTok (protein snack) and Facebook, Pinterest      │
# │  (green tea) over 3 months.                                                                                     │
# │  - Identify and partner with 10 micro-influencers per product segment (fitness + wellness) for authentic        │
# │  endorsements and user-generated content.                                                                       │
# │  - Weekly blog series and video content on clean nutrition and tea health benefits, posted on brand website     │
# │  and shared across social channels.                                                                             │
# │  - Develop branded hashtags (#FuelYourHustle, #SipSustainably) to boost community engagement.                   │
# │  - Host monthly virtual wellness events (workouts paired with green tea tasting) to drive interaction and       │
# │  loyalty.                                                                                                       │
# │  - Eco-packaging educational inserts in green tea shipments explaining sustainability story.                    │
# │  - Collaborate with health food stores and gyms for in-store tastings and sampling campaigns.                   │
# │                                                                                                                 │
# │  7. Timelines & Responsibilities                                                                                │
# │                                                                                                                 │
# │  Month 1-2:                                                                                                     │
# │  - Marketing team to finalize brand identity elements and packaging design; influencer outreach and content     │
# │  calendar development.                                                                                          │
# │  - Product development and certification verification completed.                                                │
# │                                                                                                                 │
# │  Month 3-5:                                                                                                     │
# │  - Launch social media teaser campaigns; begin influencer partnerships and content rollout.                     │
# │  - Publish blogs and video content; initiate hashtag campaigns.                                                 │
# │                                                                                                                 │
# │  Month 6:                                                                                                       │
# │  - Execute virtual wellness events and in-store samplings.                                                      │
# │  - Gather consumer feedback, monitor engagement analytics.                                                      │
# │                                                                                                                 │
# │  Month 7-8:                                                                                                     │
# │  - Review campaign effectiveness, adjust messaging or channels as necessary.                                    │
# │  - Plan next phase based on data insights.                                                                      │
# │                                                                                                                 │
# │  Responsibilities:                                                                                              │
# │  - Brand Manager: oversee creative direction and identity alignment.                                            │
# │  - Social Media Manager: campaign execution, influencer relations, content publishing.                          │
# │  - Marketing Analyst: track KPIs, consumer sentiment, competitive analysis.                                     │
# │  - PR/Events Coordinator: organize virtual and in-store events.                                                 │
# │  - Sustainability Officer: ensure packaging and messaging consistency.                                          │
# │                                                                                                                 │
# │  8. Review & Refinement                                                                                         │
# │  Before rollout, conduct a final consumer panel to validate brand messaging resonance and packaging appeal.     │
# │  Adjust language or design based on feedback to optimize market fit. Continuous monitoring of campaign KPIs     │
# │  post-launch to iteratively refine approach ensuring alignment with evolving consumer insights and brand        │
# │  values.                                                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  This end-to-end marketing and brand identity alignment plan strategically leverages detailed market insights   │
# │  to connect protein snack and organic green tea products with their ideal audiences through targeted benefits,  │
# │  compelling brand elements, and a multi-channel engagement roadmap designed to maximize consumer                │
# │  participation, build trust, and drive brand loyalty.                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
print(crew_agents_tasks_results .raw)
# Out:
# Brand Identity Alignment & Strategic Marketing Approach for Protein Snack and Organic Green Tea
#
# 1. Review & Market Positioning Summary
# Based on the previous comprehensive report, the protein snack market is rapidly growing with strong demand from Millennials and Gen Z who prioritize high protein, low sugar, clean labels, and convenience. The organic green tea market is steadily expanding with consumers emphasizing certified organic quality, sustainability, and health benefits, particularly immune support and antioxidants, appealing mainly to health-conscious Millennials and urban demographics.
#
# 2. Target Audience Segments
#
# Protein Snacks:
# - Primary: Millennials and Gen Z (ages 18-35), fitness enthusiasts, active lifestyles, urban residents seeking convenient, nutritious snacks.
# - Secondary: Health-aware professionals desiring balanced nutrition on-the-go, parents looking for healthy kid snacks.
#
# Organic Green Tea:
# - Primary: Health-conscious Millennials and urban consumers (ages 25-45), emphasizing sustainability, ethical sourcing, and antioxidant-rich beverages for wellness.
# - Secondary: Older consumers (45+) who value traditional, high-quality green tea with proven health benefits.
#
# 3. Key Product Benefits Aligned with Target Audience Preferences
#
# Protein Snack:
# - High-quality, natural protein content supporting fitness and satiety.
# - Low sugar with clean label ingredients ensuring transparency and health.
# - Ready-to-eat, convenient packaging for busy lifestyles.
# - Flavor innovation to maintain interest and enjoyment.
# - Ethical sourcing aligning with emerging sustainability concerns.
#
# Organic Green Tea:
# - Certified organic, guaranteeing purity and safety with authentic taste.
# - Sustainable and eco-friendly packaging catering to environmentally conscious consumers.
# - Rich antioxidant and anti-inflammatory properties promoting immune support and overall wellness.
# - Freshness and nutritive value to align with health priorities.
# - Story of ethical sourcing and environmental stewardship.
#
# 4. Focus Group Workshops & Brand Identity Element Brainstorming
# Facilitate interactive sessions with representatives from each target group to identify desired brand attributes and emotional triggers:
#
# Protein Snack Focus Group Insights:
# - Brand imagery evoking vitality, active lifestyle, and trustworthiness.
# - Preferred tonal language: energetic, motivating, transparent.
# - Visual elements: vibrant colors with natural tones, sleek modern packaging design.
# - Tagline suggestions: “Fuel Your Hustle” / “Power Naturally” / “Clean Energy Bites.”
#
# Organic Green Tea Focus Group Insights:
# - Brand identity around harmony, purity, and sustainability.
# - Language: calm, refreshing, reassuring.
# - Visual elements: earthy green shades, minimalist eco-friendly packaging, nature-inspired visuals.
# - Taglines: “Nature’s Purest Brew” / “Sip Sustainably, Live Healthily.”
#
# 5. Comprehensive Marketing Strategy
#
# Product Identity Presentation:
# - Protein Snack: Position as the clean, innovative protein source for on-the-go health-focused consumers. Use brand tags emphasizing natural energy and transparency. Incorporate vibrant, active lifestyle imagery and straightforward health claims on packaging and advertising.
# - Organic Green Tea: Highlight certified organic status, sustainability credentials, and health benefits with storytelling marketing. Use serene visual branding with green and earth tones, eco-friendly packaging highlights, and customer testimonials.
#
# Key Marketing Components:
# - Social media campaigns targeting fitness and wellness communities for protein snack, using influencers who align with clean eating and active lifestyle. Instagram reels, TikTok challenges demonstrating usage in workout routines.
# - Organic Green Tea campaigns focusing on sustainability and wellness influencers, educational content on health benefits via blogs and YouTube, and partnerships with eco-conscious online retailers.
# - Cross-promotion strategies bundling protein snacks with green tea as complementary health products.
#
# 6. Action Plan with Market Engagement Activities
#
# Action Items:
# - Launch teaser campaign and product reveals on Instagram, TikTok (protein snack) and Facebook, Pinterest (green tea) over 3 months.
# - Identify and partner with 10 micro-influencers per product segment (fitness + wellness) for authentic endorsements and user-generated content.
# - Weekly blog series and video content on clean nutrition and tea health benefits, posted on brand website and shared across social channels.
# - Develop branded hashtags (#FuelYourHustle, #SipSustainably) to boost community engagement.
# - Host monthly virtual wellness events (workouts paired with green tea tasting) to drive interaction and loyalty.
# - Eco-packaging educational inserts in green tea shipments explaining sustainability story.
# - Collaborate with health food stores and gyms for in-store tastings and sampling campaigns.
#
# 7. Timelines & Responsibilities
#
# Month 1-2:
# - Marketing team to finalize brand identity elements and packaging design; influencer outreach and content calendar development.
# - Product development and certification verification completed.
#
# Month 3-5:
# - Launch social media teaser campaigns; begin influencer partnerships and content rollout.
# - Publish blogs and video content; initiate hashtag campaigns.
#
# Month 6:
# - Execute virtual wellness events and in-store samplings.
# - Gather consumer feedback, monitor engagement analytics.
#
# Month 7-8:
# - Review campaign effectiveness, adjust messaging or channels as necessary.
# - Plan next phase based on data insights.
#
# Responsibilities:
# - Brand Manager: oversee creative direction and identity alignment.
# - Social Media Manager: campaign execution, influencer relations, content publishing.
# - Marketing Analyst: track KPIs, consumer sentiment, competitive analysis.
# - PR/Events Coordinator: organize virtual and in-store events.
# - Sustainability Officer: ensure packaging and messaging consistency.
#
# 8. Review & Refinement
# Before rollout, conduct a final consumer panel to validate brand messaging resonance and packaging appeal. Adjust language or design based on feedback to optimize market fit. Continuous monitoring of campaign KPIs post-launch to iteratively refine approach ensuring alignment with evolving consumer insights and brand values.
#
# ---
#
# This end-to-end marketing and brand identity alignment plan strategically leverages detailed market insights to connect protein snack and organic green tea products with their ideal audiences through targeted benefits, compelling brand elements, and a multi-channel engagement roadmap designed to maximize consumer participation, build trust, and drive brand loyalty.

# %% [markdown]
# #  Make your logical decisions with  a simple example using CrewAI’s flow pipeline

# %%
# I am interested in showing how CrewAI’s takes decision from my workflow engine

# %%
"""
My expectated outcome is win or lose or draw. This is the main goal of this project.
"""
# Out:
# '\nMy expectated outcome is win or lose or draw. This is the main goal of this project. \n'

# %%
import nest_asyncio

# Need to run all code lines without any error.
nest_asyncio.apply()


import random   #  expected:  random results such as draw, lose, and win

from crewai.flow.flow import Flow   # used for defining a workflow in crewai

from crewai.flow.flow import listen # Need to listen input data while flowing.

from crewai.flow.flow import router # Choose a path while the data flows.

from crewai.flow.flow import start # Help to initialize my project workflow (from here, my project starts).

from pydantic import BaseModel # input data flows a fixed data structure.



# State a data structure to hold the state of a match.
class MatchState(BaseModel):
  outcome: str = 'awaiting_result'  # expected results : 'draw', 'lose', 'win'



# state the match flow
class MatchFlow(Flow[MatchState]):

  @start()
  def start_match(self):
    print('the match start from here')

    # randomly select one of the three match results
    self.state.outcome = random.choice(['draw', 'lose', 'win'])
    print(f'Outcome: {self.state.outcome}')

  # flow starts from here.
  @router(start_match)
  def decide_route(self):
    # Choose the next step according to the state’s outcome.
    return self.state.outcome

  @listen('draw')
  def draw_outcome(self):
    print('final result is draw.')

  @listen('lose')
  def loss_notification(self):
    print('you lost match.')

  @listen('win')
  def win_notification(self):
    print('finalley, you got it.')


flow = MatchFlow()
flow.kickoff()
# Out:
# Flow started with ID: 6ef51bc2-efe8-4e6f-8dbd-b8585d7938a3
# WARNING:crewai.flow.flow:Flow started with ID: 6ef51bc2-efe8-4e6f-8dbd-b8585d7938a3
# ╭──────────────────────────────────────────────── Flow Execution ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: MatchFlow                                                                                                │
# │  ID: 6ef51bc2-efe8-4e6f-8dbd-b8585d7938a3                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# the match start from here
# Outcome: lose
# you lost match.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
"""
# Final Thoughts:

•	CrewAI is used to make Agentic AI systems which can show decision autonomy with adaptive task coordination.
•	Successfully made multi-agent workflows pipeline.
•	LLM decision-making is integrated with applied AI systems within multi-agent control.
•	Project is usable for data science/data analytic/NLP/LLM/AI engineering.

"""
