# %%
"""
# Workflow Title:

Multi-Agent Workflow using CrewAI for Self-Operating Culinary Task Creation

# Overview:
•	CrewAI used for a team of agents communication is applicable for making independent AI workflows.
•	Agents can communicate tasks, synchronize knowledge, and yield reliable outputs
•	one example to support CrewAI self-operating AI pipeline included.
•	This project illustrates how AI carries a real-world multi-agent workflow in practical scenarios.

"""

# %%
"""
# Underlying Technologies:

•	Python programming
•	Google Colab
•	OpenAI: gpt-4o-mini as LLM
•	CrewAI used for multi-actor workflow including task conversation under the LLM infrastructure
•	Query Engineering under LLM

# Mission:

•	Make self-managed multi-agent system and run it.
•	Communicate between agents to make personalized recipes by keeping food preference rules.
•	Make logical decisions with a simple example using CrewAI’s flow pipeline.
•	Reproducible output received.

"""

# %%
"""
# Notable Points:

•	Created a multi-agent workflow under CrewAI.
•	culinary_agent working as LLM agent can understand how to manage food elements, nutritional restrictions, and user preferences.
•	Organized tasks through multiple ways: recipe planning, tuning, and result presentation
•	Presented self-directed engine using agentic logic and AI query structuring.
•	AI pipelines working under NLP fields.

"""

# %%
import os

# %%
#%%capture
# !pip install crewai

# %%
# using 'userdata' to read key
from google.colab import userdata

api_key = userdata.get('OPENAI_API_KEY')

os.environ['OPENAI_API_KEY'] = api_key

# %%
from crewai import LLM

#from crewai import Agent, Task, Crew, LLM

# setup an LLM with OpenAI model ('gpt-4o-mini')

llm = LLM(model = 'gpt-4o-mini')

# %%
# agent input setup

flavor_bases = ['garlic', 'chicken', 'mushroom', 'tofu']

food_allergies = ['nuts',  'red meat', 'high sodium', 'spicy foods']

# %%
from crewai import Agent

# change lists into text.
flavor_bases_list_text = ','.join(flavor_bases)
food_allergies_list_text = ','.join(food_allergies)

# Note: Do not rename the keyword arguments llm, role, backstory, goal, or verbose placed inside the Agent().

culinary_agent =  Agent(
    llm=llm,
    role = 'culinary_agent',
    backstory=(
        'You are a professional culinary AI helper with clear understanding how to build recipes through smart taste matching and nutritional knowledge.'
        'You make meals that use recipe elements with respect to all food sensitivities.'),
    goal = (
    f'Make recipes which incorporate any of the highlighted flavor components: {flavor_bases_list_text}.'
    f'Drop out any food items connected to these dietary boundaries: {food_allergies_list_text}.'
    f'After selecting a recipe, guide the user with clear instructions of the cooking protocol.'
),
    verbose=True,
)

"""
For general understanding about crewai, I use one Agent() in this CrewAI task. With CrewAI, we can choose more than one Agent(). Each Agent has a different role,
goal, and backstory with different responsibilities. For example, we can choose 2 Agents such as culinary_agent, and dietary_agent.

 """
# Out:
# '\nFor general understanding about crewai, I use one Agent() in this CrewAI task. With CrewAI, we can choose more than one Agent(). Each Agent has a different role,\ngoal, and backstory with different responsibilities. For example, we can choose 2 Agents such as culinary_agent, and dietary_agent.\n\n '

# %%
# I am defining 3 tasks with 1 agent. However, CrewAI gives opportunities to choose any number of tasks with 1 or more different agents.

# %%
from crewai import Task

# Task 1: Search recipe choices according to flavor_bases, and food_allergies

search_recipes_task  =  Task(
    description = ('Use the provided flavor parts, drop avoided allergens, and make at least three recipes with core components and a short explanation.'),

    expected_output = ' Provide a minimum of 3 recipes along with an overview of necessary ingredients.',

    agent = culinary_agent,
)

# %%
# Task 2: Take your best recipe.
select_best_recipe_task = Task(
    description = (
        'Overview all suggested recipes and then analyze them.'
        'Select a recipe that has test quality as well as dietary criteria.'
        'Give us some reasons behind your decision.'),

    expected_output = 'Final recipe as well as reasoning for your choice.',

    agent = culinary_agent,)

# %%
# Task # 3: Make an end-to-end recipe workflow
make_cooking_steps_task = Task(
    description = (
        'Put the selected recipe into an organized as well as clear explained cooking manual.'
        'Provide some details including cooking time, temperature limit, and helpful recommendations.'),

    expected_output = 'provide a completed cooking instructions in sequential order.',

    agent = culinary_agent,)

# %%
# State the Crew with a agent and tasks
# are tasks required in order? Left for research
# Define the Crew (group of agents + tasks working in sequence)

from crewai import Crew

kitchen_crew  = Crew(
    agents = [culinary_agent],
    tasks  =  [search_recipes_task, select_best_recipe_task, make_cooking_steps_task],
    planning = True,
    verbose = True,
)

# %%
# Run all tasks if they are in order.
outcomes_culinary_crew = kitchen_crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: c9b2e232-53c9-42d6-8f2b-23cec78e50b6                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [2025-11-06 14:58:09][INFO]: Planning the crew execution
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 366bc581-6b9c-410e-83b6-0a82c47af75c                                                                     │
# │  Agent: Task Execution Planner                                                                                  │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: culinary_agent                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Below are three delicious recipes that incorporate the selected flavor components of garlic, chicken,          │
# │  mushroom, and tofu while avoiding any allergens such as nuts, red meat, high sodium, and spicy foods. Each     │
# │  recipe is designed to highlight flavors and provide clear instructions for preparation.                        │
# │                                                                                                                 │
# │  ### Recipe 1: Garlic Chicken and Mushroom Stir-Fry                                                             │
# │  **Core Components:**                                                                                           │
# │  - Chicken breasts, sliced                                                                                      │
# │  - Fresh mushrooms (button or cremini), sliced                                                                  │
# │  - Garlic, minced                                                                                               │
# │  - Bell pepper, sliced (for color and sweetness)                                                                │
# │  - Olive oil                                                                                                    │
# │  - Low-sodium soy sauce (optional)                                                                              │
# │  - Green onions, chopped (for garnish)                                                                          │
# │                                                                                                                 │
# │  **Preparation Method:**                                                                                        │
# │  1. In a large skillet, heat 1 tablespoon of olive oil over medium heat.                                        │
# │  2. Add minced garlic to the skillet and sauté for about 30 seconds until fragrant.                             │
# │  3. Increase the heat and add the sliced chicken. Stir-fry for 5-7 minutes until cooked through.                │
# │  4. Add the sliced mushrooms and bell peppers to the skillet. Stir to combine and sauté for an additional 3-5   │
# │  minutes until vegetables are tender.                                                                           │
# │  5. If desired, drizzle a small amount of low-sodium soy sauce. Serve hot, garnished with chopped green         │
# │  onions.                                                                                                        │
# │                                                                                                                 │
# │  ### Recipe 2: Tofu and Garlic Mushroom Soup                                                                    │
# │  **Core Components:**                                                                                           │
# │  - Firm tofu, cubed                                                                                             │
# │  - Fresh mushrooms, sliced                                                                                      │
# │  - Garlic, minced                                                                                               │
# │  - Vegetable broth (low sodium)                                                                                 │
# │  - Spinach leaves                                                                                               │
# │  - Green onions, chopped                                                                                        │
# │  - Olive oil                                                                                                    │
# │                                                                                                                 │
# │  **Preparation Method:**                                                                                        │
# │  1. In a pot, heat 1 tablespoon of olive oil over medium heat. Add minced garlic and sauté for about 30         │
# │  seconds.                                                                                                       │
# │  2. Stir in the sliced mushrooms and cook for about 5 minutes, until they release their moisture and become     │
# │  tender.                                                                                                        │
# │  3. Pour in vegetable broth and bring to a boil.                                                                │
# │  4. Reduce the heat and add cubed tofu and spinach. Let simmer for about 5 minutes until heated through.        │
# │  5. Serve hot, garnished with chopped green onions.                                                             │
# │                                                                                                                 │
# │  ### Recipe 3: Garlic Herb Chicken and Tofu Skewers                                                             │
# │  **Core Components:**                                                                                           │
# │  - Chicken breasts, cut into chunks                                                                             │
# │  - Firm tofu, pressed and cut into cubes                                                                        │
# │  - Garlic, minced                                                                                               │
# │  - Mixed herbs (such as thyme and rosemary)                                                                     │
# │  - Olive oil                                                                                                    │
# │  - Bell peppers and cherry tomatoes (for skewering)                                                             │
# │                                                                                                                 │
# │  **Preparation Method:**                                                                                        │
# │  1. Preheat the grill or grill pan to medium-high heat.                                                         │
# │  2. In a bowl, combine minced garlic, olive oil, and mixed herbs to create a marinade.                          │
# │  3. Add the chicken chunks and tofu cubes to the marinade, tossing to coat. Let sit for 15-30 minutes.          │
# │  4. Thread the marinated chicken, tofu, bell peppers, and cherry tomatoes onto skewers.                         │
# │  5. Grill the skewers for about 10-15 minutes, turning occasionally, until chicken is cooked through and has    │
# │  nice grill marks.                                                                                              │
# │                                                                                                                 │
# │  These three recipes offer a variety of flavors and cooking styles while adhering to dietary needs. Enjoy your  │
# │  cooking!                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: c69d4e1e-a52e-4b2c-89fc-0f9d39fc38c4                                                                     │
# │  Agent: culinary_agent                                                                                          │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: culinary_agent                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  After reviewing the three recipes, the following analyses were conducted based on taste quality (taste and     │
# │  preparation ease) and dietary compliance with the outlined requirements.                                       │
# │                                                                                                                 │
# │  ### Recipe Analyses:                                                                                           │
# │                                                                                                                 │
# │  **Recipe 1: Garlic Chicken and Mushroom Stir-Fry**                                                             │
# │  - **Taste Quality:** This recipe is flavorful due to the combination of sautéed garlic, chicken, and           │
# │  mushrooms. The addition of bell peppers adds sweetness and texture. The potential use of low-sodium soy sauce  │
# │  enhances umami flavor without contributing high sodium levels. Preparation is straightforward, with minimal    │
# │  cooking time (approximately 15 minutes).                                                                       │
# │  - **Dietary Compliance:** Fully adheres to dietary restrictions, avoiding nuts, red meat, high sodium, and     │
# │  spicy foods while incorporating garlic and chicken prominently.                                                │
# │                                                                                                                 │
# │  **Recipe 2: Tofu and Garlic Mushroom Soup**                                                                    │
# │  - **Taste Quality:** This soup offers a comforting and earthy flavor profile primarily driven by garlic,       │
# │  mushrooms, and the addition of spinach. It is easy to prepare, with a cooking time of around 15-20 minutes.    │
# │  The warmth of the broth makes it very appealing but may be seen as less satisfying by some who prefer solid    │
# │  meals.                                                                                                         │
# │  - **Dietary Compliance:** This recipe is also compliant with the dietary restrictions, as it avoids the        │
# │  prohibited food items. It includes tofu and garlic, making it a nutritious option.                             │
# │                                                                                                                 │
# │  **Recipe 3: Garlic Herb Chicken and Tofu Skewers**                                                             │
# │  - **Taste Quality:** The skewers are flavorful due to the marinated chicken and tofu, along with the grilled   │
# │  bell peppers and cherry tomatoes. The grilling method imparts a nice smoky flavor and appealing texture. The   │
# │  preparation requires more time (including marinating time), approximately 40-45 minutes in total.              │
# │  - **Dietary Compliance:** This recipe meets all dietary criteria, involving no nuts, red meat, high sodium,    │
# │  or spicy foods while integrating chicken, tofu, and garlic.                                                    │
# │                                                                                                                 │
# │  ### Selected Recipe                                                                                            │
# │  After careful consideration, **Recipe 1: Garlic Chicken and Mushroom Stir-Fry** is selected as it best meets   │
# │  both taste criteria and dietary restrictions.                                                                  │
# │                                                                                                                 │
# │  ### Reasons for Selection:                                                                                     │
# │  1. **Taste Balance:** This recipe has the perfect blend of flavors from garlic, tender chicken, and earthy     │
# │  mushrooms, enhanced by colorful bell peppers. The simplicity and freshness provide a vibrant dish that is      │
# │  likely to appeal to a variety of palates.                                                                      │
# │  2. **Healthfulness:** Utilizing olive oil and low-sodium soy sauce keeps the dish heart-healthy. The fast      │
# │  cooking method helps maintain the nutrients of vegetables and keeps the chicken moist and flavorful.           │
# │  3. **Simplicity:** Taking only about 15 minutes to prepare, this recipe is accessible for all skill levels.    │
# │  It presents a quick and healthy meal solution for both busy weeknights and leisurely weekends.                 │
# │                                                                                                                 │
# │  In conclusion, the Garlic Chicken and Mushroom Stir-Fry is not only deliciously flavorful but also aligns      │
# │  perfectly with the dietary requirements, making it an excellent choice for diverse meals.                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 82cd870e-3987-4a48-87bc-f023673e7469                                                                     │
# │  Agent: culinary_agent                                                                                          │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: culinary_agent                                                                                          │
# │                                                                                                                 │
# │  Task: Put the selected recipe into an organized as well as clear explained cooking manual.Provide some         │
# │  details including cooking time, temperature limit, and helpful recommendations.1. Take the selected recipe     │
# │  from Task Number 2. 2. Organize the recipe into a cooking manual format. 3. Include all critical information:  │
# │  ingredients list, cooking time, temperature limits, and the sequential steps of preparation. 4. Add helpful    │
# │  recommendations for cooking tips, substitution options for ingredients if any, and ways to enhance flavor      │
# │  while keeping within dietary needs. 5. Ensure that the manual is clear, concise, and easy to follow for        │
# │  someone attempting the recipe for the first time.                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: culinary_agent                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Cooking Manual: Garlic Chicken and Mushroom Stir-Fry                                                       │
# │                                                                                                                 │
# │  #### Ingredients:                                                                                              │
# │  - 1 pound chicken breasts, sliced                                                                              │
# │  - 8 ounces fresh mushrooms (button or cremini), sliced                                                         │
# │  - 3 cloves garlic, minced                                                                                      │
# │  - 1 bell pepper (red, yellow, or green), sliced                                                                │
# │  - 1 tablespoon olive oil                                                                                       │
# │  - 1 tablespoon low-sodium soy sauce (optional)                                                                 │
# │  - 2 green onions, chopped (for garnish)                                                                        │
# │                                                                                                                 │
# │  #### Cooking Time:                                                                                             │
# │  - **Preparation Time:** 5 minutes                                                                              │
# │  - **Cooking Time:** 10-15 minutes                                                                              │
# │  - **Total Time:** Approximately 15-20 minutes                                                                  │
# │                                                                                                                 │
# │  #### Temperature:                                                                                              │
# │  - **Stove Top Heat:** Medium to high                                                                           │
# │                                                                                                                 │
# │  ### Preparation Steps:                                                                                         │
# │  1. **Preheat the Skillet:** Place a large skillet on the stove and heat it over medium heat.                   │
# │                                                                                                                 │
# │  2. **Sauté Garlic:** Add 1 tablespoon of olive oil to the skillet. Once the oil is hot (but not smoking), add  │
# │  3 cloves of minced garlic. Sauté for about 30 seconds until fragrant, being careful not to let it burn.        │
# │                                                                                                                 │
# │  3. **Cook Chicken:** Increase the heat to medium-high and add the sliced chicken breasts to the skillet.       │
# │  Stir-fry the chicken for 5-7 minutes until it is fully cooked and no longer pink in the center.                │
# │                                                                                                                 │
# │  4. **Add Vegetables:** Once the chicken is cooked, add the sliced mushrooms and bell pepper to the skillet.    │
# │  Stir everything to combine. Continue to sauté for another 3-5 minutes until the mushrooms are tender and the   │
# │  bell peppers are slightly softened.                                                                            │
# │                                                                                                                 │
# │  5. **Optional Soy Sauce:** If desired, drizzle a small amount of low-sodium soy sauce over the mixture. Stir   │
# │  to combine and ensure that everything is evenly coated. Cook for an additional minute.                         │
# │                                                                                                                 │
# │  6. **Serve:** Remove from heat and transfer the stir-fry to a serving plate. Garnish with chopped green        │
# │  onions for a fresh touch. Serve hot.                                                                           │
# │                                                                                                                 │
# │  ### Helpful Recommendations:                                                                                   │
# │  - **Cooking Tips:** Ensure the skillet is hot enough before adding the chicken to achieve a good sear. Stir    │
# │  frequently to prevent sticking and promote even cooking.                                                       │
# │  - **Substitutions:** If desired, you can replace chicken with tofu for a vegetarian option. Simply cube firm   │
# │  tofu and lightly sauté it for 5-7 minutes before adding the vegetables.                                        │
# │  - **Enhancing Flavor:** You can add a splash of lemon juice or a sprinkle of fresh herbs (like parsley or      │
# │  basil) before serving to enhance the freshness of the dish.                                                    │
# │  - **Leftover Storage:** Store any leftovers in an airtight container in the refrigerator for up to 2 days.     │
# │  Reheat thoroughly before serving.                                                                              │
# │                                                                                                                 │
# │  Enjoy your delicious Garlic Chicken and Mushroom Stir-Fry, a quick, nutritious, and flavorful meal that fits   │
# │  well with dietary restrictions!                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# Like to see clean text

print(outcomes_culinary_crew.raw)
# Out:
# ### Cooking Manual: Garlic Chicken and Mushroom Stir-Fry
#
# #### Ingredients:
# - 1 pound chicken breasts, sliced
# - 8 ounces fresh mushrooms (button or cremini), sliced
# - 3 cloves garlic, minced
# - 1 bell pepper (red, yellow, or green), sliced
# - 1 tablespoon olive oil
# - 1 tablespoon low-sodium soy sauce (optional)
# - 2 green onions, chopped (for garnish)
#
# #### Cooking Time:
# - **Preparation Time:** 5 minutes
# - **Cooking Time:** 10-15 minutes
# - **Total Time:** Approximately 15-20 minutes
#
# #### Temperature:
# - **Stove Top Heat:** Medium to high
#
# ### Preparation Steps:
# 1. **Preheat the Skillet:** Place a large skillet on the stove and heat it over medium heat.
#
# 2. **Sauté Garlic:** Add 1 tablespoon of olive oil to the skillet. Once the oil is hot (but not smoking), add 3 cloves of minced garlic. Sauté for about 30 seconds until fragrant, being careful not to let it burn.
#
# 3. **Cook Chicken:** Increase the heat to medium-high and add the sliced chicken breasts to the skillet. Stir-fry the chicken for 5-7 minutes until it is fully cooked and no longer pink in the center.
#
# 4. **Add Vegetables:** Once the chicken is cooked, add the sliced mushrooms and bell pepper to the skillet. Stir everything to combine. Continue to sauté for another 3-5 minutes until the mushrooms are tender and the bell peppers are slightly softened.
#
# 5. **Optional Soy Sauce:** If desired, drizzle a small amount of low-sodium soy sauce over the mixture. Stir to combine and ensure that everything is evenly coated. Cook for an additional minute.
#
# 6. **Serve:** Remove from heat and transfer the stir-fry to a serving plate. Garnish with chopped green onions for a fresh touch. Serve hot.
#
# ### Helpful Recommendations:
# - **Cooking Tips:** Ensure the skillet is hot enough before adding the chicken to achieve a good sear. Stir frequently to prevent sticking and promote even cooking.
# - **Substitutions:** If desired, you can replace chicken with tofu for a vegetarian option. Simply cube firm tofu and lightly sauté it for 5-7 minutes before adding the vegetables.
# - **Enhancing Flavor:** You can add a splash of lemon juice or a sprinkle of fresh herbs (like parsley or basil) before serving to enhance the freshness of the dish.
# - **Leftover Storage:** Store any leftovers in an airtight container in the refrigerator for up to 2 days. Reheat thoroughly before serving.
#
# Enjoy your delicious Garlic Chicken and Mushroom Stir-Fry, a quick, nutritious, and flavorful meal that fits well with dietary restrictions!

# %% [markdown]
# # using CrewAI for marketing research with multiple products

# %%
#%%capture
# !pip install crewai-tools

# %%
# SerperDevTool acting as a tool to search real time internet data.

from crewai_tools import SerperDevTool

# %%
market_products_list =  [ 'protein snack', 'organic green tea']


marketing_experience = [
    'A goal focused marketing way supports on promoting healthy snacks as well as organic drinks with keeping brand name and holding customer participation.',
    'A marketing data analyst skilled in understanding consumer behavior, market competition, and campaigning strategies for healthy snacks, and organic beverages.',
    'A marketing expert showed for planning to launch products, research on market trends, and find target audiences for protein snack, organic green tea, and other healthy products.'
]

# %%
market_products_list_text = ','.join(market_products_list)
marketing_experience_text = ','.join(marketing_experience)

# %%
# Import necessary CrewAI classes

from crewai import Agent

# Agent # 1: Market Trends Specialist
Market_trends_specialist = Agent(
    role = 'Market Trends Specialist',

    goal = (f'Research on market patterns, understand buyer habits, and observe competitive approaches: {market_products_list_text}.'),

    backstory=('You have enough skills for market research as well asl market analysis.'
        ' Good experience for analyzing market signals and finding market growth possibilities.'),

    tools=[SerperDevTool()],
    verbose = True)

# %%
# Agent # 2: make some strategies based on market analysis

advisor = Agent(
    role = 'product improvement strategist',

    goal=(
        'Use market understanding to find results focused '
        f'marketing and Product identity approaches for these items: {market_products_list_text}.'),

    backstory=(
        f' You have solid experience in {marketing_experience_text}, so that your role is good for a brand strategist.'),
    verbose=True)

# %%
#  Task # 1: Run market analysis
collect_market_analysis_task  = Task(
    description=(
        f'Run online research to take key market patterns,'
        f'For {market_products_list_text}, it is demanding to focus for customer interest and market competition.'),

    expected_output = (
        'Report on current market patterns, and main competitors  including consumer preferences.'),
    agent = Market_trends_specialist)

# %%
# Task # 2: Generate market brand strategy plan

generate_market_brand_strategy_plan = Task(
    description=(
        f'make Brand identity alignment with best product using strategic approach involved in {market_products_list_text}.'
        'cover the focus group, and Key benefits with action plan.'
    ),

    expected_output = 'End to end marketing approach with covering target audience, and recommended actions  for market strategy.',

    agent = advisor,

    verbose = True
)

# %%
# link agents with tasks using Crew

crew_agents_tasks = Crew(

    agents = [Market_trends_specialist, advisor],

    tasks = [collect_market_analysis_task, generate_market_brand_strategy_plan],

    planning = True,

    verbose = True
)

# %%
from getpass import getpass

os.environ['SERPER_API_KEY'] = getpass('Super api key ')

print('super api key loaded and hided.')
# Out:
# Super api key ··········
# super api key loaded and hided.

# %%
# Run pipeline
crew_agents_tasks_results = crew_agents_tasks.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 43768270-aa86-4fba-9ade-5ffe2e5a5d12                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# [2025-11-06 15:00:43][INFO]: Planning the crew execution
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 13b20173-66e6-4864-8db3-4a280f588a70                                                                     │
# │  Agent: Task Execution Planner                                                                                  │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Trends Specialist                                                                                │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "current market patterns for protein snacks and organic green tea, consumer preferences      │
# │  protein snacks, market competition organic green tea"                                                          │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'current market patterns for protein snacks and organic green tea, consumer         │
# │  preferences protein snacks, market competition organic green tea', 'type': 'search', 'num': 10, 'engine':      │
# │  'google'}, 'organic': [{'title': 'Protein Snacks Market Size, Share & Trends | Forecast [2032]', 'link':       │
# │  'https://www.fortunebusinessinsights.com/protein-snacks-market-110937', 'snippet': 'The global protein snacks  │
# │  market size was valued at $46.49 billion in 2023 & is projected to grow from $50.48 billion in 2024 to         │
# │  $100.56 billion by 2032.', 'position': 1}, {'title': 'Protein Snacks Market Size, Share | CAGR of 8.8%',       │
# │  'link': 'https://market.us/report/global-protein-snacks-market/', 'snippet': 'Protein Snacks Market size is    │
# │  expected to be worth around USD 10.5 Billion by 2034, from USD 4.5 Billion in 2024, at a CAGR of 8.8%',        │
# │  'position': 2}, {'title': 'Healthy Snacks Market Size, Share & Trends Report, 2030', 'link':                   │
# │  'https://www.grandviewresearch.com/industry-analysis/healthy-snack-market', 'snippet': 'The global healthy     │
# │  snacks market size was estimated at USD 95.61 billion in 2023 and is expected to grow at a CAGR of 6.2% from   │
# │  2024 to 2030.', 'position': 3}, {'title': 'Protein Snacks Market Size, Share & Growth Report, 2025', 'link':   │
# │  'https://www.persistencemarketresearch.com/market-research/protein-snacks-market.asp', 'snippet': 'The         │
# │  protein snacks market is projected to reach US$ 4,796.3 Mn in 2025, with a CAGR of 8.7% from 2025 to 2032.     │
# │  Plant-based snacks are expected ...', 'position': 4}, {'title': 'Protein Snacks Market Size, Share & 2030      │
# │  Trends Report', 'link': 'https://www.mordorintelligence.com/industry-reports/protein-snacks-market',           │
# │  'snippet': 'The Protein Snacks Market is expected to reach USD 32.01 billion in 2025 and grow at a CAGR of     │
# │  7.68% to reach USD 46.34 billion by 2030.', 'position': 5}, {'title': 'US Organic Snacks Market: By Type -     │
# │  LinkedIn', 'link': 'https://www.linkedin.com/pulse/us-organic-snacks-market-type-datacraft-market-qvtuc'...    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Trends Specialist                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  [Deliver full report as above]                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: product improvement strategist                                                                          │
# │                                                                                                                 │
# │  Task: make Brand identity alignment with best product using strategic approach involved in protein             │
# │  snack,organic green tea.cover the focus group, and Key benefits with action plan.1. Analyze the findings from  │
# │  the previous task regarding market trends and consumer preferences for protein snacks and organic green tea.   │
# │  2. Identify the key benefits and differentiators that can be leveraged in the brand identity for both          │
# │  products. 3. Define the focus group for brand identity alignment based on demographics, preferences, and       │
# │  buying behavior observed in the research. 4. Outline the core elements of the current brand identity for both  │
# │  products. 5. Develop a strategic marketing approach that aligns with consumer interests and highlights key     │
# │  benefits. 6. Create an action plan including specific recommendations for enhancing brand visibility and       │
# │  resonance with the target audience. 7. Collaborate with team members to gather input on proposed changes or    │
# │  strategies. 8. Present the end-to-end marketing approach to stakeholders, ensuring it covers clearly defined   │
# │  target audience segments and suggests actionable items for implementation. 9. Finalize the brand identity      │
# │  alignment strategy based on feedback from stakeholders. 10. Prepare documentation for the marketing strategy   │
# │  including timelines and expected outcomes.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 339f2aa5-3eb3-491d-8611-27533274eccc                                                                     │
# │  Agent: Market Trends Specialist                                                                                │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: product improvement strategist                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Brand Identity Alignment and Strategic Marketing Approach for Protein Snack & Organic Green Tea                │
# │                                                                                                                 │
# │  1. Market Trends and Consumer Preferences Analysis                                                             │
# │                                                                                                                 │
# │  - Protein Snacks: The growing health-conscious consumer base prioritizes high-protein, clean-label snacks      │
# │  that support fitness, muscle recovery, and sustained energy. Trends indicate a preference for plant-based      │
# │  proteins, allergen-free formulations, and convenient on-the-go packaging. Consumers seek snacks without        │
# │  artificial preservatives or additives, favoring natural ingredients and functional benefits such as digestive  │
# │  health or low glycemic index.                                                                                  │
# │                                                                                                                 │
# │  - Organic Green Tea: Demand is rising for organic, sustainably sourced beverages with confirmed health         │
# │  benefits like antioxidants, detoxification, and mental calmness. Younger consumers and wellness-focused        │
# │  adults prefer authentic, pure green tea with transparency in organic certification. Eco-conscious packaging    │
# │  and storytelling around origin and ethical farming practices enhance appeal.                                   │
# │                                                                                                                 │
# │  2. Key Benefits and Differentiators for Brand Identity                                                         │
# │                                                                                                                 │
# │  Protein Snack:                                                                                                 │
# │  - High protein content derived from clean, plant-based or natural sources                                      │
# │  - Allergen-friendly and free from artificial additives                                                         │
# │  - Convenient, portable packaging catering to active lifestyles                                                 │
# │  - Functional benefits such as muscle recovery, satiety, and digestive wellness                                 │
# │                                                                                                                 │
# │  Organic Green Tea:                                                                                             │
# │  - Certified organic and sustainably sourced from reputable regions                                             │
# │  - Rich in antioxidants and natural compounds promoting wellness and relaxation                                 │
# │  - Authentic taste, minimally processed, retaining natural nutrients                                            │
# │  - Eco-friendly packaging emphasizing environmental responsibility and provenance transparency                  │
# │                                                                                                                 │
# │  3. Focus Group Definition for Brand Identity Alignment                                                         │
# │                                                                                                                 │
# │  - Demographics:                                                                                                │
# │    - Age: 25-45 years old                                                                                       │
# │    - Gender: Both male and female, with slight skew toward female consumers for organic tea                     │
# │    - Income: Middle to upper-middle income, willing to invest in premium health products                        │
# │    - Geography: Urban and suburban areas with access to specialty retail and online channels                    │
# │                                                                                                                 │
# │  - Preferences and Buying Behavior:                                                                             │
# │    - Health-conscious individuals pursuing fitness and wellness                                                 │
# │    - Millennials and Gen Z valuing sustainability, transparency, and natural products                           │
# │    - Busy professionals and active lifestyle consumers prioritizing convenient nutrition                        │
# │    - Socially and environmentally aware consumers supporting ethical brands                                     │
# │                                                                                                                 │
# │  4. Core Elements of Current Brand Identity                                                                     │
# │                                                                                                                 │
# │  Protein Snack:                                                                                                 │
# │  - Brand positioning as a natural, high-protein, guilt-free snack option                                        │
# │  - Emphasis on clean ingredients and functional health benefits                                                 │
# │  - Visual identity features earthy tones and active lifestyle imagery                                           │
# │                                                                                                                 │
# │  Organic Green Tea:                                                                                             │
# │  - Brand values centered on purity, sustainability, and authentic wellness                                      │
# │  - Messaging highlighting organic certification and ethical sourcing                                            │
# │  - Packaging with minimalist design, green color palette evoking nature and calm                                │
# │                                                                                                                 │
# │  5. Strategic Marketing Approach                                                                                │
# │                                                                                                                 │
# │  - Messaging Strategy:                                                                                          │
# │    - Communicate clear product benefits aligned with consumer motivations: “Fuel your body naturally” (protein  │
# │  snack) and “Pure calm in every cup” (green tea).                                                               │
# │    - Highlight key differentiators: clean protein sources and all-natural formulations for snacks; certified    │
# │  organic origin and antioxidant benefits for tea.                                                               │
# │                                                                                                                 │
# │  - Channel Strategy:                                                                                            │
# │    - Strengthen presence on digital platforms popular with target segments (Instagram, health & wellness        │
# │  blogs, fitness forums).                                                                                        │
# │    - Leverage influencer partnerships with fitness trainers, nutritionists, and eco-conscious lifestyle         │
# │  advocates.                                                                                                     │
# │    - Expand availability through online direct-to-consumer channels and premium retail.                         │
# │                                                                                                                 │
# │  - Engagement Strategy:                                                                                         │
# │    - Interactive campaigns encouraging user-generated content such as #SnackSmart and #TeaTimeRitual.           │
# │    - Educational content on benefits of protein and organic green tea via blogs, videos, and webinars.          │
# │    - Loyalty programs rewarding repeat customers and brand ambassadors.                                         │
# │                                                                                                                 │
# │  - Packaging and Product Innovation:                                                                            │
# │    - Develop resealable, eco-friendly packaging to enhance convenience and sustainability perception.           │
# │    - Introduce limited edition flavors or seasonal blends to stimulate trial and retention.                     │
# │                                                                                                                 │
# │  6. Action Plan for Enhancing Brand Visibility & Resonance                                                      │
# │                                                                                                                 │
# │  - Immediate (0-3 months):                                                                                      │
# │    - Conduct workshops with team to finalize messaging and visual assets incorporating stakeholder feedback.    │
# │    - Launch targeted digital ads focusing on product benefits and eco-friendly brand story.                     │
# │    - Initiate influencer marketing collaborations and schedule content calendar.                                │
# │                                                                                                                 │
# │  - Mid-term (3-6 months):                                                                                       │
# │    - Roll out interactive social media campaigns aligned with health and wellness events.                       │
# │    - Launch updated packaging with transparent ingredient labels and eco messaging.                             │
# │    - Offer introductory promotions and bundle deals through e-commerce platforms.                               │
# │                                                                                                                 │
# │  - Long-term (6-12 months):                                                                                     │
# │    - Monitor campaign performance; refine targeting and creative based on analytics.                            │
# │    - Develop subscription models for convenient replenishment.                                                  │
# │    - Expand retail partnerships in health food chains and specialty stores.                                     │
# │    - Host community events and wellness workshops to deepen engagement.                                         │
# │                                                                                                                 │
# │  7. Collaboration with Team Members                                                                             │
# │                                                                                                                 │
# │  - Schedule regular cross-functional meetings to incorporate input from product development, marketing, and     │
# │  sales teams.                                                                                                   │
# │  - Use collaborative platforms to gather ongoing feedback on campaign assets and new product concepts.          │
# │  - Engage customer service teams to relay consumer insights and emergent trends back to marketing efforts.      │
# │                                                                                                                 │
# │  8. Presentation to Stakeholders                                                                                │
# │                                                                                                                 │
# │  - Prepare comprehensive presentation covering:                                                                 │
# │    - Detailed consumer insights and focus group profiles                                                        │
# │    - Defined brand values and differentiators tailored to target audience                                       │
# │    - Multi-channel strategic marketing plan with clear KPIs                                                     │
# │    - Stepwise action plan with timelines and resource allocation                                                │
# │  - Include projected outcomes such as increased brand awareness, higher engagement rates, and sales growth      │
# │  targets.                                                                                                       │
# │  - Solicit stakeholder feedback actively and document agreed modifications.                                     │
# │                                                                                                                 │
# │  9. Finalization of Brand Identity Alignment Strategy                                                           │
# │                                                                                                                 │
# │  - Refine messaging and visuals post stakeholder input.                                                         │
# │  - Confirm integration of sustainability and convenience as pillars of identity for both products.              │
# │  - Align marketing calendar with product launch cycles and seasonal opportunities.                              │
# │  - Establish monitoring system for ongoing brand perception tracking.                                           │
# │                                                                                                                 │
# │  10. Documentation of Marketing Strategy                                                                        │
# │                                                                                                                 │
# │  - Compile a detailed marketing strategy document encapsulating:                                                │
# │    - Market analysis and target audience profiles                                                               │
# │    - Brand identity elements and value propositions for protein snack and organic green tea                     │
# │    - Channel and communication strategies                                                                       │
# │    - Specific actions, timelines, and responsible teams                                                         │
# │    - Expected outcomes including measurable KPIs and ROI projections                                            │
# │  - Prepare executive summary and supporting materials for dissemination.                                        │
# │                                                                                                                 │
# │  Conclusion:                                                                                                    │
# │  This end-to-end marketing approach strategically aligns the brand identity of the protein snack and organic    │
# │  green tea with emerging consumer demands and market trends. By clearly defining target audiences,              │
# │  highlighting unique product benefits, and deploying a multi-faceted marketing plan with measurable actions,    │
# │  the brand will strengthen its market position, enhance visibility, and drive sustainable growth.               │
# │                                                                                                                 │
# │  This comprehensive strategy ensures the brand resonates deeply with health-conscious, eco-aware consumers      │
# │  seeking convenient and authentic wellness products, thus delivering robust outcomes and competitive advantage  │
# │  in the healthy snacks and organic beverage categories.                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
print(crew_agents_tasks_results .raw)
# Out:
# Brand Identity Alignment and Strategic Marketing Approach for Protein Snack & Organic Green Tea
#
# 1. Market Trends and Consumer Preferences Analysis
#
# - Protein Snacks: The growing health-conscious consumer base prioritizes high-protein, clean-label snacks that support fitness, muscle recovery, and sustained energy. Trends indicate a preference for plant-based proteins, allergen-free formulations, and convenient on-the-go packaging. Consumers seek snacks without artificial preservatives or additives, favoring natural ingredients and functional benefits such as digestive health or low glycemic index.
#
# - Organic Green Tea: Demand is rising for organic, sustainably sourced beverages with confirmed health benefits like antioxidants, detoxification, and mental calmness. Younger consumers and wellness-focused adults prefer authentic, pure green tea with transparency in organic certification. Eco-conscious packaging and storytelling around origin and ethical farming practices enhance appeal.
#
# 2. Key Benefits and Differentiators for Brand Identity
#
# Protein Snack:
# - High protein content derived from clean, plant-based or natural sources
# - Allergen-friendly and free from artificial additives
# - Convenient, portable packaging catering to active lifestyles
# - Functional benefits such as muscle recovery, satiety, and digestive wellness
#
# Organic Green Tea:
# - Certified organic and sustainably sourced from reputable regions
# - Rich in antioxidants and natural compounds promoting wellness and relaxation
# - Authentic taste, minimally processed, retaining natural nutrients
# - Eco-friendly packaging emphasizing environmental responsibility and provenance transparency
#
# 3. Focus Group Definition for Brand Identity Alignment
#
# - Demographics:
#   - Age: 25-45 years old
#   - Gender: Both male and female, with slight skew toward female consumers for organic tea
#   - Income: Middle to upper-middle income, willing to invest in premium health products
#   - Geography: Urban and suburban areas with access to specialty retail and online channels
#
# - Preferences and Buying Behavior:
#   - Health-conscious individuals pursuing fitness and wellness
#   - Millennials and Gen Z valuing sustainability, transparency, and natural products
#   - Busy professionals and active lifestyle consumers prioritizing convenient nutrition
#   - Socially and environmentally aware consumers supporting ethical brands
#
# 4. Core Elements of Current Brand Identity
#
# Protein Snack:
# - Brand positioning as a natural, high-protein, guilt-free snack option
# - Emphasis on clean ingredients and functional health benefits
# - Visual identity features earthy tones and active lifestyle imagery
#
# Organic Green Tea:
# - Brand values centered on purity, sustainability, and authentic wellness
# - Messaging highlighting organic certification and ethical sourcing
# - Packaging with minimalist design, green color palette evoking nature and calm
#
# 5. Strategic Marketing Approach
#
# - Messaging Strategy:
#   - Communicate clear product benefits aligned with consumer motivations: “Fuel your body naturally” (protein snack) and “Pure calm in every cup” (green tea).
#   - Highlight key differentiators: clean protein sources and all-natural formulations for snacks; certified organic origin and antioxidant benefits for tea.
#
# - Channel Strategy:
#   - Strengthen presence on digital platforms popular with target segments (Instagram, health & wellness blogs, fitness forums).
#   - Leverage influencer partnerships with fitness trainers, nutritionists, and eco-conscious lifestyle advocates.
#   - Expand availability through online direct-to-consumer channels and premium retail.
#
# - Engagement Strategy:
#   - Interactive campaigns encouraging user-generated content such as #SnackSmart and #TeaTimeRitual.
#   - Educational content on benefits of protein and organic green tea via blogs, videos, and webinars.
#   - Loyalty programs rewarding repeat customers and brand ambassadors.
#
# - Packaging and Product Innovation:
#   - Develop resealable, eco-friendly packaging to enhance convenience and sustainability perception.
#   - Introduce limited edition flavors or seasonal blends to stimulate trial and retention.
#
# 6. Action Plan for Enhancing Brand Visibility & Resonance
#
# - Immediate (0-3 months):
#   - Conduct workshops with team to finalize messaging and visual assets incorporating stakeholder feedback.
#   - Launch targeted digital ads focusing on product benefits and eco-friendly brand story.
#   - Initiate influencer marketing collaborations and schedule content calendar.
#
# - Mid-term (3-6 months):
#   - Roll out interactive social media campaigns aligned with health and wellness events.
#   - Launch updated packaging with transparent ingredient labels and eco messaging.
#   - Offer introductory promotions and bundle deals through e-commerce platforms.
#
# - Long-term (6-12 months):
#   - Monitor campaign performance; refine targeting and creative based on analytics.
#   - Develop subscription models for convenient replenishment.
#   - Expand retail partnerships in health food chains and specialty stores.
#   - Host community events and wellness workshops to deepen engagement.
#
# 7. Collaboration with Team Members
#
# - Schedule regular cross-functional meetings to incorporate input from product development, marketing, and sales teams.
# - Use collaborative platforms to gather ongoing feedback on campaign assets and new product concepts.
# - Engage customer service teams to relay consumer insights and emergent trends back to marketing efforts.
#
# 8. Presentation to Stakeholders
#
# - Prepare comprehensive presentation covering:
#   - Detailed consumer insights and focus group profiles
#   - Defined brand values and differentiators tailored to target audience
#   - Multi-channel strategic marketing plan with clear KPIs
#   - Stepwise action plan with timelines and resource allocation
# - Include projected outcomes such as increased brand awareness, higher engagement rates, and sales growth targets.
# - Solicit stakeholder feedback actively and document agreed modifications.
#
# 9. Finalization of Brand Identity Alignment Strategy
#
# - Refine messaging and visuals post stakeholder input.
# - Confirm integration of sustainability and convenience as pillars of identity for both products.
# - Align marketing calendar with product launch cycles and seasonal opportunities.
# - Establish monitoring system for ongoing brand perception tracking.
#
# 10. Documentation of Marketing Strategy
#
# - Compile a detailed marketing strategy document encapsulating:
#   - Market analysis and target audience profiles
#   - Brand identity elements and value propositions for protein snack and organic green tea
#   - Channel and communication strategies
#   - Specific actions, timelines, and responsible teams
#   - Expected outcomes including measurable KPIs and ROI projections
# - Prepare executive summary and supporting materials for dissemination.
#
# Conclusion:
# This end-to-end marketing approach strategically aligns the brand identity of the protein snack and organic green tea with emerging consumer demands and market trends. By clearly defining target audiences, highlighting unique product benefits, and deploying a multi-faceted marketing plan with measurable actions, the brand will strengthen its market position, enhance visibility, and drive sustainable growth.
#
# This comprehensive strategy ensures the brand resonates deeply with health-conscious, eco-aware consumers seeking convenient and authentic wellness products, thus delivering robust outcomes and competitive advantage in the healthy snacks and organic beverage categories.

# %% [markdown]
# #  Make your logical decisions with  a simple example using CrewAI’s flow pipeline

# %%
# I am interested in showing how CrewAI’s takes decision from my workflow engine

# %%
"""
My expectated outcome is win or lose or draw. This is the main goal of this project.
"""
# Out:
# '\nMy expectated outcome is win or lose or draw. This is the main goal of this project. \n'

# %%
import nest_asyncio

# Need to run all code lines without any error.
nest_asyncio.apply()


import random   #  expected:  random results such as draw, lose, and win

from crewai.flow.flow import Flow   # used for defining a workflow in crewai

from crewai.flow.flow import listen # Need to listen input data while flowing.

from crewai.flow.flow import router # Choose a path while the data flows.

from crewai.flow.flow import start # Help to initialize my project workflow (from here, my project starts).

from pydantic import BaseModel # input data flows a fixed data structure.



# State a data structure to hold the state of a match.
class MatchState(BaseModel):
  outcome: str = 'awaiting_result'  # expected results : 'draw', 'lose', 'win'



# state the match flow
class MatchFlow(Flow[MatchState]):

  @start()
  def start_match(self):
    print('the match start from here')

    # randomly select one of the three match results
    self.state.outcome = random.choice(['draw', 'lose', 'win'])
    print(f'Outcome: {self.state.outcome}')

  # flow starts from here.
  @router(start_match)
  def decide_route(self):
    # Choose the next step according to the state’s outcome.
    return self.state.outcome

  @listen('draw')
  def draw_outcome(self):
    print('final result is draw.')

  @listen('lose')
  def loss_notification(self):
    print('you lost match.')

  @listen('win')
  def win_notification(self):
    print('finalley, you got it.')


flow = MatchFlow()
flow.kickoff()
# Out:
# WARNING:crewai.flow.flow:Flow started with ID: fc776a76-d867-48c2-9d54-f087f29cf65a
# Flow started with ID: fc776a76-d867-48c2-9d54-f087f29cf65a
# ╭──────────────────────────────────────────────── Flow Execution ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: MatchFlow                                                                                                │
# │  ID: fc776a76-d867-48c2-9d54-f087f29cf65a                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# the match start from here
# Outcome: lose
# you lost match.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Flow Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Flow Execution Completed                                                                                       │
# │  Name: MatchFlow                                                                                                │
# │  ID: fc776a76-d867-48c2-9d54-f087f29cf65a                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
"""
# Final Thoughts:

•	CrewAI is used to make Agentic AI systems which can show decision autonomy with adaptive task coordination.
•	Successfully made multi-agent workflows pipeline.
•	LLM decision-making is integrated with applied AI systems within multi-agent control.
•	Project is usable for data science/data analytic/NLP/LLM/AI engineering.

"""
